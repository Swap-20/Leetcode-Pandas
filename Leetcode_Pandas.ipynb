# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %% [markdown]
# ##### 584 - Find Customer Referee
#
# Find the names of the customer that are not referred by the customer with id = 2.
#
# Return the result table in any order.

# %%
data = [[1, 'Will', None], [2, 'Jane', None], [3, 'Alex', 2], [4, 'Bill', None], [5, 'Zack', 1], [6, 'Mark', 2]]

customer = pd.DataFrame(data, columns=['id', 'name', 'referee_id']).astype({'id':'Int64', 'name':'object', 'referee_id':'Int64'})

customer
# Out:
#    id  name  referee_id
# 0   1  Will        <NA>
# 1   2  Jane        <NA>
# 2   3  Alex           2
# 3   4  Bill        <NA>
# 4   5  Zack           1
# 5   6  Mark           2

# %%
df = customer[(customer['referee_id'] != 2) | (customer['referee_id'].isna())]
df
# Out:
#    id  name  referee_id
# 0   1  Will        <NA>
# 1   2  Jane        <NA>
# 3   4  Bill        <NA>
# 4   5  Zack           1

# %% [markdown]
# #### 595 - Big Countries
#
# Find name, population and country with at least 30 million or it has population of atleast 25 million

# %%
data = [['Afghanistan', 'Asia', 652230, 25500100, 20343000000], ['Albania', 'Europe', 28748, 2831741, 12960000000], ['Algeria', 'Africa', 2381741, 37100000, 188681000000], ['Andorra', 'Europe', 468, 78115, 3712000000], ['Angola', 'Africa', 1246700, 20609294, 100990000000]]

world = pd.DataFrame(data, columns=['name', 'continent', 'area', 'population', 'gdp']).astype({'name':'object', 'continent':'object', 'area':'Int64', 'population':'Int64', 'gdp':'Int64'})
world
# Out:
#           name continent     area  population           gdp
# 0  Afghanistan      Asia   652230    25500100   20343000000
# 1      Albania    Europe    28748     2831741   12960000000
# 2      Algeria    Africa  2381741    37100000  188681000000
# 3      Andorra    Europe      468       78115    3712000000
# 4       Angola    Africa  1246700    20609294  100990000000

# %%
df = world[(world["area"] >= 3000000) | (world["population"] >= 25000000)]
df
# Out:
#           name continent     area  population           gdp
# 0  Afghanistan      Asia   652230    25500100   20343000000
# 2      Algeria    Africa  2381741    37100000  188681000000

# %% [markdown]
# #### 1757 - Recyclable and Low Fat Products
#
# Find ids of product that are both low fat and recyclable.

# %%
data = [['0', 'Y', 'N'], ['1', 'Y', 'Y'], ['2', 'N', 'Y'], ['3', 'Y', 'Y'], ['4', 'N', 'N']]

products = pd.DataFrame(data, columns=['product_id', 'low_fats', 'recyclable']).astype({'product_id':'int64', 'low_fats':'category', 'recyclable':'category'})
products
# Out:
#    product_id low_fats recyclable
# 0           0        Y          N
# 1           1        Y          Y
# 2           2        N          Y
# 3           3        Y          Y
# 4           4        N          N

# %%
df = products[(products['low_fats'] ==  'Y') & (products['recyclable'] == 'Y')]
df
# Out:
#    product_id low_fats recyclable
# 1           1        Y          Y
# 3           3        Y          Y

# %% [markdown]
# #### 183 - Customers who never orders
#
# Find customer who never order anything

# %%
data = [[1, 'Joe'], [2, 'Henry'], [3, 'Sam'], [4, 'Max']]

customers = pd.DataFrame(data, columns=['id', 'name']).astype({'id':'Int64', 'name':'object'})

data = [[1, 3], [2, 1]]

orders = pd.DataFrame(data, columns=['id', 'customerId']).astype({'id':'Int64', 'customerId':'Int64'})

df = pd.merge(customers, orders, how='left', on='id')
df
# Out:
#    id   name  customerId
# 0   1    Joe           3
# 1   2  Henry           1
# 2   3    Sam        <NA>
# 3   4    Max        <NA>

# %%
#list of customer who placed orders
customer_list = orders['customerId'].unique().tolist()
customer_list
# Out:
# [3, 1]

# %%
#remove customers who never order
customers = customers[~customers["id"].isin(customer_list)]

#rename column name
customers = customers.rename(columns={"name":"Customers"})
customers[['Customers']]
# Out:
#   Customers
# 1     Henry
# 3       Max

# %% [markdown]
# #### 1148 - Article Views I
#
# Find authors who viewed atleast 1 of their own articles. Return table sorted by id in ascending order

# %%
data = [[1, 3, 5, '2019-08-01'], [1, 3, 6, '2019-08-02'], [2, 7, 7, '2019-08-01'], [2, 7, 6, '2019-08-02'], [4, 7, 1, '2019-07-22'], [3, 4, 4, '2019-07-21'], [3, 4, 4, '2019-07-21']]

views = pd.DataFrame(data, columns=['article_id', 'author_id', 'viewer_id', 'view_date']).astype({'article_id':'Int64', 'author_id':'Int64', 'viewer_id':'Int64', 'view_date':'datetime64[ns]'})

views
# Out:
#    article_id  author_id  viewer_id  view_date
# 0           1          3          5 2019-08-01
# 1           1          3          6 2019-08-02
# 2           2          7          7 2019-08-01
# 3           2          7          6 2019-08-02
# 4           4          7          1 2019-07-22
# 5           3          4          4 2019-07-21
# 6           3          4          4 2019-07-21

# %%
#identify authors who viewed their own article
df = views[views['author_id'] == views['viewer_id']]
df
# Out:
#    article_id  author_id  viewer_id  view_date
# 2           2          7          7 2019-08-01
# 5           3          4          4 2019-07-21
# 6           3          4          4 2019-07-21

# %%
df = df.drop_duplicates(subset=['author_id'])
df
# Out:
#    article_id  author_id  viewer_id  view_date
# 2           2          7          7 2019-08-01
# 5           3          4          4 2019-07-21

# %%
#sort by author_id ascending order
sorted_df = df.sort_values(by=['author_id'])

# %%
sorted_df[['author_id']]
# Out:
#    author_id
# 5          4
# 2          7

# %%
sorted_df.rename(columns={'author_id':'id'},inplace=True)
sorted_df[['id']]
# Out:
#    id
# 5   4
# 2   7

# %% [markdown]
# #### 1683 - Invalid Tweets
#
# Find ids of invalid tweets. tweet is invalid if the no. of character used in content is greater than 15

# %%
data = [[1, 'Let us Code'], [2, 'More than fifteen chars are here!']]
tweets = pd.DataFrame(data, columns=['tweet_id', 'content']).astype({'tweet_id':'Int64', 'content':'object'})
tweets
# Out:
#    tweet_id                            content
# 0         1                        Let us Code
# 1         2  More than fifteen chars are here!

# %%
df = tweets[tweets['content'].str.len() > 15][['tweet_id']]
df
# Out:
#    tweet_id
# 1         2

# %% [markdown]
# #### 1608 - Product Sales Analysis I
#
# Write a solution to report the product_name, year, and price for each sale_id in the Sales table.
#
# Return the resulting table in any order.

# %%
data = [[1, 100, 2008, 10, 5000], [2, 100, 2009, 12, 5000], [7, 200, 2011, 15, 9000]]
sales = pd.DataFrame(data, columns=['sale_id', 'product_id', 'year', 'quantity', 'price']).astype({'sale_id':'Int64', 'product_id':'Int64', 'year':'Int64', 'quantity':'Int64', 'price':'Int64'})
sales
# Out:
#    sale_id  product_id  year  quantity  price
# 0        1         100  2008        10   5000
# 1        2         100  2009        12   5000
# 2        7         200  2011        15   9000

# %%
data = [[100, 'Nokia'], [200, 'Apple'], [300, 'Samsung']]
product = pd.DataFrame(data, columns=['product_id', 'product_name']).astype({'product_id':'Int64', 'product_name':'object'})
product
# Out:
#    product_id product_name
# 0         100        Nokia
# 1         200        Apple
# 2         300      Samsung

# %%
df = sales.merge(product, how='left', on='product_id')
df
# Out:
#    sale_id  product_id  year  quantity  price product_name
# 0        1         100  2008        10   5000        Nokia
# 1        2         100  2009        12   5000        Nokia
# 2        7         200  2011        15   9000        Apple

# %%
result = df[['product_name', 'year', 'price']]
result
# Out:
#   product_name  year  price
# 0        Nokia  2008   5000
# 1        Nokia  2009   5000
# 2        Apple  2011   9000

# %% [markdown]
# #### 1661 - Average Time of Process per Machine
#
# There is a factory website that has several machines each running the same number of processes. Write a solution to find the average time each machine takes to complete a process.
#
# The time to complete a process is the 'end' timestamp minus the 'start' timestamp. The average time is calculated by the total time to complete every process on the machine divided by the number of processes that were run.
#
# The resulting table should have the machine_id along with the average time as processing_time, which should be rounded to 3 decimal places.
#
# Return the result table in any order.

# %%
data = [[0, 0, 'start', 0.712], [0, 0, 'end', 1.52], [0, 1, 'start', 3.14], [0, 1, 'end', 4.12], [1, 0, 'start', 0.55], [1, 0, 'end', 1.55], [1, 1, 'start', 0.43], [1, 1, 'end', 1.42], [2, 0, 'start', 4.1], [2, 0, 'end', 4.512], [2, 1, 'start', 2.5], [2, 1, 'end', 5]]
activity = pd.DataFrame(data, columns=['machine_id', 'process_id', 'activity_type', 'timestamp']).astype({'machine_id':'Int64', 'process_id':'Int64', 'activity_type':'object', 'timestamp':'Float64'})
activity
# Out:
#     machine_id  process_id activity_type  timestamp
# 0            0           0         start      0.712
# 1            0           0           end       1.52
# 2            0           1         start       3.14
# 3            0           1           end       4.12
# 4            1           0         start       0.55
# 5            1           0           end       1.55
# 6            1           1         start       0.43
# 7            1           1           end       1.42
# 8            2           0         start        4.1
# 9            2           0           end      4.512
# 10           2           1         start        2.5
# 11           2           1           end        5.0

# %%
start = activity[activity['activity_type'] == 'start'][['machine_id','process_id','timestamp']]
start
# Out:
#     machine_id  process_id  timestamp
# 0            0           0      0.712
# 2            0           1       3.14
# 4            1           0       0.55
# 6            1           1       0.43
# 8            2           0        4.1
# 10           2           1        2.5

# %%
end = activity[activity['activity_type'] == 'end'][['machine_id','process_id','timestamp']]
end
# Out:
#     machine_id  process_id  timestamp
# 1            0           0       1.52
# 3            0           1       4.12
# 5            1           0       1.55
# 7            1           1       1.42
# 9            2           0      4.512
# 11           2           1        5.0

# %%
merged = pd.merge(start,end, on=['machine_id', 'process_id'],suffixes=('_start', '_end'))
merged
# Out:
#    machine_id  process_id  timestamp_start  timestamp_end
# 0           0           0            0.712           1.52
# 1           0           1             3.14           4.12
# 2           1           0             0.55           1.55
# 3           1           1             0.43           1.42
# 4           2           0              4.1          4.512
# 5           2           1              2.5            5.0

# %%
result = merged.assign(processing_time = merged['timestamp_end'] - merged['timestamp_start']).groupby('machine_id')['processing_time'].mean().round(3).reset_index()
result
# Out:
#    machine_id  processing_time
# 0           0            0.894
# 1           1            0.995
# 2           2            1.456

# %% [markdown]
# #### 1873 - Calculate Special Bonus
#
# Calculate the bonus of each employee. The bonus of an employee is 100% of their salary if the ID of the employee is an odd number and the employee's name does not start with the character 'M'. The bonus of an employee is 0 otherwise.
#
# Return the result table ordered by employee_id.

# %%
data = [[2, 'Meir', 3000], [3, 'Michael', 3800], [7, 'Addilyn', 7400], [8, 'Juan', 6100], [9, 'Kannon', 7700]]
employees = pd.DataFrame(data, columns=['employee_id', 'name', 'salary']).astype({'employee_id':'int64', 'name':'object', 'salary':'int64'})
employees
# Out:
#    employee_id     name  salary
# 0            2     Meir    3000
# 1            3  Michael    3800
# 2            7  Addilyn    7400
# 3            8     Juan    6100
# 4            9   Kannon    7700

# %%
df = employees[employees['name'].str.contains("M")  & employees['employee_id'] % 2 != 0]
df
# Out:
#    employee_id     name  salary
# 1            3  Michael    3800

# %%
employees['bonus'] = employees.apply(
    lambda x:x['salary'] if x['employee_id'] % 2  and not x['name'].startswith('M') else 0,
    axis = 1
)
df = employees[['employee_id','bonus']].sort_values('employee_id')
df
# Out:
#    employee_id  bonus
# 0            2      0
# 1            3      0
# 2            7   7400
# 3            8      0
# 4            9   7700

# %% [markdown]
# #### 1581 - Customer who visited but did not make any transactions
#
# Write a solution to find the IDs of the users who visited without making any transactions and the number of times they made these types of visits.
#
# Return the result table sorted in any order.

# %%
data = [[1, 23], [2, 9], [4, 30], [5, 54], [6, 96], [7, 54], [8, 54]]
visits = pd.DataFrame(data, columns=['visit_id', 'customer_id']).astype({'visit_id':'Int64', 'customer_id':'Int64'})
visits
# Out:
#    visit_id  customer_id
# 0         1           23
# 1         2            9
# 2         4           30
# 3         5           54
# 4         6           96
# 5         7           54
# 6         8           54

# %%
data = [[2, 5, 310], [3, 5, 300], [9, 5, 200], [12, 1, 910], [13, 2, 970]]
transactions = pd.DataFrame(data, columns=['transaction_id', 'visit_id', 'amount']).astype({'transaction_id':'Int64', 'visit_id':'Int64', 'amount':'Int64'})
transactions
# Out:
#    transaction_id  visit_id  amount
# 0               2         5     310
# 1               3         5     300
# 2               9         5     200
# 3              12         1     910
# 4              13         2     970

# %%
df = visits.merge(transactions, how='left', on='visit_id')
df
# Out:
#    visit_id  customer_id  transaction_id  amount
# 0         1           23              12     910
# 1         2            9              13     970
# 2         4           30            <NA>    <NA>
# 3         5           54               2     310
# 4         5           54               3     300
# 5         5           54               9     200
# 6         6           96            <NA>    <NA>
# 7         7           54            <NA>    <NA>
# 8         8           54            <NA>    <NA>

# %%
no_transactions = df[df['transaction_id'].isna()]
no_transactions
# Out:
#    visit_id  customer_id  transaction_id  amount
# 2         4           30            <NA>    <NA>
# 6         6           96            <NA>    <NA>
# 7         7           54            <NA>    <NA>
# 8         8           54            <NA>    <NA>

# %%
transaction_count = no_transactions.groupby('customer_id')[['customer_id']].value_counts().reset_index()
transaction_count
# Out:
#    customer_id  count
# 0           30      1
# 1           54      2
# 2           96      1

# %% [markdown]
# #### 197 - Rising Temperature
#
# Write a solution to find all dates' id with higher temperatures compared to its previous dates (yesterday).
#
# Return the result table in any order.

# %%
data = [[1, '2015-01-01', 10], [2, '2015-01-02', 25], [3, '2015-01-03', 20], [4, '2015-01-04', 30]]
weather = pd.DataFrame(data, columns=['id', 'recordDate', 'temperature']).astype({'id':'Int64', 'recordDate':'datetime64[ns]', 'temperature':'Int64'})
weather
# Out:
#    id recordDate  temperature
# 0   1 2015-01-01           10
# 1   2 2015-01-02           25
# 2   3 2015-01-03           20
# 3   4 2015-01-04           30

# %%
weather['PrevTemp'] = weather['temperature'].shift(1)
weather
# Out:
#    id recordDate  temperature  PrevTemp
# 0   1 2015-01-01           10      <NA>
# 1   2 2015-01-02           25        10
# 2   3 2015-01-03           20        25
# 3   4 2015-01-04           30        20

# %%
weather['PrevDate'] = weather['recordDate'].shift(1)
weather
# Out:
#    id recordDate  temperature  PrevTemp   PrevDate
# 0   1 2015-01-01           10      <NA>        NaT
# 1   2 2015-01-02           25        10 2015-01-01
# 2   3 2015-01-03           20        25 2015-01-02
# 3   4 2015-01-04           30        20 2015-01-03

# %%
weather['Diff'] = (weather['recordDate'] - weather['PrevDate']).dt.days

# %%
output = weather[(weather['Diff'] == 1) & (weather['PrevTemp'] < weather['temperature'])]
output
# Out:
#    id recordDate  temperature  PrevTemp   PrevDate  Diff
# 1   2 2015-01-02           25        10 2015-01-01   1.0
# 3   4 2015-01-04           30        20 2015-01-03   1.0

# %%
output[['id']]
# Out:
#    id
# 1   2
# 3   4

# %% [markdown]
# #### 1667 - Fix names in the table
#
# Fix the names so that only the first character is uppercase and the rest are lowercase.
#
# Return the result table ordered by user_id.

# %%
data = [[1, 'aLice'], [2, 'bOB']]
users = pd.DataFrame(data, columns=['user_id', 'name']).astype({'user_id':'Int64', 'name':'object'})
users
# Out:
#    user_id   name
# 0        1  aLice
# 1        2    bOB

# %%
users['name'] = users['name'].str.capitalize()
users
# Out:
#    user_id   name
# 0        1  Alice
# 1        2    Bob

# %% [markdown]
# #### 1517 - Find users with valid e-mails
#
# Find the users who have valid emails.
#
# A valid e-mail has a prefix name and a domain where:
#
# The prefix name is a string that may contain letters (upper or lower case), digits, underscore '_', period '.', and/or dash '-'. The prefix name must start with a letter.
# The domain is '@leetcode.com'.

# %%
data = [[1, 'Winston', 'winston@leetcode.com'], [2, 'Jonathan', 'jonathanisgreat'], [3, 'Annabelle', 'bella-@leetcode.com'], [4, 'Sally', 'sally.come@leetcode.com'], [5, 'Marwan', 'quarz#2020@leetcode.com'], [6, 'David', 'david69@gmail.com'], [7, 'Shapiro', '.shapo@leetcode.com']]

users = pd.DataFrame(data, columns=['user_id', 'name', 'mail']).astype({'user_id':'int64', 'name':'object', 'mail':'object'})
users
# Out:
#    user_id       name                     mail
# 0        1    Winston     winston@leetcode.com
# 1        2   Jonathan          jonathanisgreat
# 2        3  Annabelle      bella-@leetcode.com
# 3        4      Sally  sally.come@leetcode.com
# 4        5     Marwan  quarz#2020@leetcode.com
# 5        6      David        david69@gmail.com
# 6        7    Shapiro      .shapo@leetcode.com

# %% [markdown]
# #### 1527 - Patients with a condition
#
# Find the patient_id, patient_name, and conditions of the patients who have Type I Diabetes. Type I Diabetes always starts with DIAB1 prefix.

# %%
data = [[1, 'Daniel', 'YFEV COUGH'], [2, 'Alice', ''], [3, 'Bob', 'DIAB100 MYOP'], [4, 'George', 'ACNE DIAB100'], [5, 'Alain', 'DIAB201']]

patients = pd.DataFrame(data, columns=['patient_id', 'patient_name', 'conditions']).astype({'patient_id':'int64', 'patient_name':'object', 'conditions':'object'})
patients
# Out:
#    patient_id patient_name    conditions
# 0           1       Daniel    YFEV COUGH
# 1           2        Alice
# 2           3          Bob  DIAB100 MYOP
# 3           4       George  ACNE DIAB100
# 4           5        Alain       DIAB201

# %%
patients[patients['conditions'].str.contains('DIAB1')]
# Out:
#    patient_id patient_name    conditions
# 2           3          Bob  DIAB100 MYOP
# 3           4       George  ACNE DIAB100

# %% [markdown]
# #### 177 - Nth Highes Salary
#
# Find the nth highest distinct salary from the Employee table. If there are less than n distinct salaries, return null.

# %%
data = [[1, 100], [2, 200], [3, 300]]

employee = pd.DataFrame(data, columns=['Id', 'Salary']).astype({'Id':'Int64', 'Salary':'Int64'})

# %% [markdown]
# ### 176 - Second highest salary

# %%
data = [[1,100],[2,200],[3,300]]
employee = pd.DataFrame(data, columns=['id','salary'])
employee
# Out:
#    id  salary
# 0   1     100
# 1   2     200
# 2   3     300

# %%
employee['rank'] = employee[['salary']].rank(ascending=False)
employee
# Out:
#    id  salary  rank
# 0   1     100   3.0
# 1   2     200   2.0
# 2   3     300   1.0

# %%
type(employee[employee['rank'] == 2][['salary']])
# Out:
# pandas.core.frame.DataFrame

# %%
employee[employee['rank'] == 2][['salary']]
# Out:
#    salary
# 1     200

# %%
employee[employee['rank'] == 2][['salary']].rename(columns={'salary':'SecondHighestSalary'})
# Out:
#    SecondHighestSalary
# 1                  200

# %%
# If No highest salary return Null or None
data = [[1,100]]
employee1 = pd.DataFrame(data, columns=['id','salary'])
employee1
# Out:
#    id  salary
# 0   1     100

# %%
employee1['rank'] = employee1[['salary']].rank(ascending=False)
employee1
# Out:
#    id  salary  rank
# 0   1     100   1.0

# %%
employee1[employee1['rank'] == 2][['salary']].rename(columns={'salary':'SecondHighestSalary'})
# Out:
# Empty DataFrame
# Columns: [SecondHighestSalary]
# Index: []

# %% [markdown]
# #### 184 - Department Highest salary
#
# find employees who have the highest salary in each of the departments.

# %%
data = [[1, 'Joe', 70000, 1], [2, 'Jim', 90000, 1], [3, 'Henry', 80000, 2], [4, 'Sam', 60000, 2], [5, 'Max', 90000, 1]]

employee = pd.DataFrame(data, columns=['id', 'name', 'salary', 'departmentId']).astype({'id':'Int64', 'name':'object', 'salary':'Int64', 'departmentId':'Int64'})

data = [[1, 'IT'], [2, 'Sales']]

department = pd.DataFrame(data, columns=['id', 'name']).astype({'id':'Int64', 'name':'object'})

# %%
employee
# Out:
#    id   name  salary  departmentId
# 0   1    Joe   70000             1
# 1   2    Jim   90000             1
# 2   3  Henry   80000             2
# 3   4    Sam   60000             2
# 4   5    Max   90000             1

# %%
department
# Out:
#    id   name
# 0   1     IT
# 1   2  Sales

# %%
pd.merge(employee, department, left_on='departmentId', right_on='id', how='left', suffixes=('_emp', '_dep'))
# Out:
#    id_emp name_emp  salary  departmentId  id_dep name_dep
# 0       1      Joe   70000             1       1       IT
# 1       2      Jim   90000             1       1       IT
# 2       3    Henry   80000             2       2    Sales
# 3       4      Sam   60000             2       2    Sales
# 4       5      Max   90000             1       1       IT

# %%
df = employee.groupby('departmentId')['salary'].max().reset_index().rename(columns={'salary':'max_salary'})
df
# Out:
#    departmentId  max_salary
# 0             1       90000
# 1             2       80000

# %%
df2 = df.merge(df, on='departmentId', how='left')
df2
# Out:
#    departmentId  max_salary_x  max_salary_y
# 0             1         90000         90000
# 1             2         80000         80000

# %% [markdown]
# ### 178 - Rank Scores

# %%
data = [[1, 3.5], [2, 3.65], [3, 4.0], [4, 3.85], [5, 4.0], [6, 3.65]]
scores = pd.DataFrame(data, columns=['id', 'score']).astype({'id':'Int64', 'score':'Float64'})

# %%
scores
# Out:
#    id  score
# 0   1    3.5
# 1   2   3.65
# 2   3    4.0
# 3   4   3.85
# 4   5    4.0
# 5   6   3.65

# %%
sorted_df = scores.sort_values(by='score', ascending=False)
sorted_df
# Out:
#    id  score
# 4   5    4.0
# 2   3    4.0
# 3   4   3.85
# 1   2   3.65
# 5   6   3.65
# 0   1    3.5

# %%
sorted_df['score'].rank(method='dense')
# Out:
# 4    4.0
# 2    4.0
# 3    3.0
# 1    2.0
# 5    2.0
# 0    1.0
# Name: score, dtype: float64

# %%
sorted_df['rank'] = sorted_df['score'].rank(method='dense', ascending=False)
sorted_df[['score', 'rank']]
# Out:
#    score  rank
# 4    4.0   1.0
# 2    4.0   1.0
# 3   3.85   2.0
# 1   3.65   3.0
# 5   3.65   3.0
# 0    3.5   4.0

# %% [markdown]
# ### 196. Delete Duplicate Emails

# %%
data = [[1, 'john@example.com'], [2, 'bob@example.com'], [3, 'john@example.com']]
person = pd.DataFrame(data, columns=['id', 'email']).astype({'id':'int64', 'email':'object'})

# %%
person
# Out:
#    id             email
# 0   1  john@example.com
# 1   2   bob@example.com
# 2   3  john@example.com

# %%
df = person.sort_values(by=['id'],ascending=True)
df
# Out:
#    id             email
# 0   1  john@example.com
# 1   2   bob@example.com
# 2   3  john@example.com

# %%
df.drop_duplicates(subset=['email'],keep='first',inplace=True)
df
# Out:
#    id             email
# 0   1  john@example.com
# 1   2   bob@example.com

# %% [markdown]
# #### 1741 - Find total time spent by each employee
#
# Calculate the total time in minutes spent by each employee on each day at the office. Note that within one day, an employee can enter and leave more than once. The time spent in the office for a single entry is out_time - in_time.

# %%
data = [['1', '2020-11-28', '4', '32'], ['1', '2020-11-28', '55', '200'], ['1', '2020-12-3', '1', '42'], ['2', '2020-11-28', '3', '33'], ['2', '2020-12-9', '47', '74']]

employees = pd.DataFrame(data, columns=['emp_id', 'event_day', 'in_time', 'out_time']).astype({'emp_id':'Int64', 'event_day':'datetime64[ns]', 'in_time':'Int64', 'out_time':'Int64'})
employees
# Out:
#    emp_id  event_day  in_time  out_time
# 0       1 2020-11-28        4        32
# 1       1 2020-11-28       55       200
# 2       1 2020-12-03        1        42
# 3       2 2020-11-28        3        33
# 4       2 2020-12-09       47        74

# %%
#calculate time spent in each entry
employees['total_time'] = employees['out_time'] - employees['in_time']
employees
# Out:
#    emp_id  event_day  in_time  out_time  total_time
# 0       1 2020-11-28        4        32          28
# 1       1 2020-11-28       55       200         145
# 2       1 2020-12-03        1        42          41
# 3       2 2020-11-28        3        33          30
# 4       2 2020-12-09       47        74          27

# %%
df = employees.groupby(["event_day","emp_id"])['total_time'].sum()
df
# Out:
# event_day   emp_id
# 2020-11-28  1         173
#             2          30
# 2020-12-03  1          41
# 2020-12-09  2          27
# Name: total_time, dtype: Int64

# %%
df.reset_index().rename(columns={'event_day':'day'})
# Out:
#          day  emp_id  total_time
# 0 2020-11-28       1         173
# 1 2020-11-28       2          30
# 2 2020-12-03       1          41
# 3 2020-12-09       2          27

# %% [markdown]
# #### 1934 - Confirmation Rate
#
# The confirmation rate of a user is the number of 'confirmed' messages divided by the total number of requested confirmation messages. The confirmation rate of a user that did not request any confirmation messages is 0. Round the confirmation rate to two decimal places.
#
# Write a solution to find the confirmation rate of each user.
#
# Return the result table in any order.

# %%
data = [[3, '2020-03-21 10:16:13'], [7, '2020-01-04 13:57:59'], [2, '2020-07-29 23:09:44'], [6, '2020-12-09 10:39:37']]
signups = pd.DataFrame(data, columns=['user_id', 'time_stamp']).astype({'user_id':'Int64', 'time_stamp':'datetime64[ns]'})
signups
# Out:
#    user_id          time_stamp
# 0        3 2020-03-21 10:16:13
# 1        7 2020-01-04 13:57:59
# 2        2 2020-07-29 23:09:44
# 3        6 2020-12-09 10:39:37

# %%
data = [[3, '2021-01-06 03:30:46', 'timeout'], [3, '2021-07-14 14:00:00', 'timeout'], [7, '2021-06-12 11:57:29', 'confirmed'], [7, '2021-06-13 12:58:28', 'confirmed'], [7, '2021-06-14 13:59:27', 'confirmed'], [2, '2021-01-22 00:00:00', 'confirmed'], [2, '2021-02-28 23:59:59', 'timeout']]
confirmations = pd.DataFrame(data, columns=['user_id', 'time_stamp', 'action']).astype({'user_id':'Int64', 'time_stamp':'datetime64[ns]', 'action':'object'})
confirmations
# Out:
#    user_id          time_stamp     action
# 0        3 2021-01-06 03:30:46    timeout
# 1        3 2021-07-14 14:00:00    timeout
# 2        7 2021-06-12 11:57:29  confirmed
# 3        7 2021-06-13 12:58:28  confirmed
# 4        7 2021-06-14 13:59:27  confirmed
# 5        2 2021-01-22 00:00:00  confirmed
# 6        2 2021-02-28 23:59:59    timeout

# %%
df = confirmations[confirmations['action'] == 'confirmed'].groupby('user_id').size()
df
# Out:
# user_id
# 2    1
# 7    3
# dtype: int64

# %%
total = confirmations.groupby('user_id').size()
total
# Out:
# user_id
# 2    2
# 3    2
# 7    3
# dtype: int64

# %%
rate = (df/total).fillna(0).round(2)
rate
# Out:
# user_id
# 2    0.5
# 3    0.0
# 7    1.0
# dtype: float64

# %%
result = signups[['user_id']].copy()
result
# Out:
#    user_id
# 0        3
# 1        7
# 2        2
# 3        6

# %%
result['confirmation_rate'] = result['user_id'].map(rate).fillna(0).round(2)
result
# Out:
#    user_id  confirmation_rate
# 0        3                0.0
# 1        7                1.0
# 2        2                0.5
# 3        6                0.0

# %% [markdown]
# #### 511 - Game Play Analysis I
#
# Find the first login date for each player.

# %%
data = [[1, 2, '2016-03-01', 5], [1, 2, '2016-05-02', 6], [2, 3, '2017-06-25', 1], [3, 1, '2016-03-02', 0], [3, 4, '2018-07-03', 5]]

activity = pd.DataFrame(data, columns=['player_id', 'device_id', 'event_date', 'games_played']).astype({'player_id':'Int64', 'device_id':'Int64', 'event_date':'datetime64[ns]', 'games_played':'Int64'})
activity
# Out:
#    player_id  device_id event_date  games_played
# 0          1          2 2016-03-01             5
# 1          1          2 2016-05-02             6
# 2          2          3 2017-06-25             1
# 3          3          1 2016-03-02             0
# 4          3          4 2018-07-03             5

# %%
activity['first_login'] = activity.groupby('player_id')['event_date'].transform('min')
activity
# Out:
#    player_id  device_id event_date  games_played first_login
# 0          1          2 2016-03-01             5  2016-03-01
# 1          1          2 2016-05-02             6  2016-03-01
# 2          2          3 2017-06-25             1  2017-06-25
# 3          3          1 2016-03-02             0  2016-03-02
# 4          3          4 2018-07-03             5  2016-03-02

# %%
activity[['player_id','first_login']].drop_duplicates()
# Out:
#    player_id first_login
# 0          1  2016-03-01
# 2          2  2017-06-25
# 3          3  2016-03-02

# %% [markdown]
# #### 2356 - Number of unique subjects taught by each teacher
#
# calculate the number of unique subjects each teacher teaches in the university.

# %%
data = [[1, 2, 3], [1, 2, 4], [1, 3, 3], [2, 1, 1], [2, 2, 1], [2, 3, 1], [2, 4, 1]]

teacher = pd.DataFrame(data, columns=['teacher_id', 'subject_id', 'dept_id']).astype({'teacher_id':'Int64', 'subject_id':'Int64', 'dept_id':'Int64'})
teacher
# Out:
#    teacher_id  subject_id  dept_id
# 0           1           2        3
# 1           1           2        4
# 2           1           3        3
# 3           2           1        1
# 4           2           2        1
# 5           2           3        1
# 6           2           4        1

# %%
# no of unique subjects taught by each teacher
df = teacher.groupby('teacher_id')['subject_id'].nunique()
df
# Out:
# teacher_id
# 1    2
# 2    4
# Name: subject_id, dtype: int64

# %%
df.reset_index().rename(columns={'subject_id':'cnt'})
# Out:
#    teacher_id  cnt
# 0           1    2
# 1           2    4

# %% [markdown]
# #### 596 - Classes more than 5 students
#
# find all the classes that have at least five students.

# %%
data = [['A', 'Math'], ['B', 'English'], ['C', 'Math'], ['D', 'Biology'], ['E', 'Math'], ['F', 'Computer'], ['G', 'Math'], ['H', 'Math'], ['I', 'Math']]
courses = pd.DataFrame(data, columns=['student', 'class']).astype({'student':'object', 'class':'object'})
courses
# Out:
#   student     class
# 0       A      Math
# 1       B   English
# 2       C      Math
# 3       D   Biology
# 4       E      Math
# 5       F  Computer
# 6       G      Math
# 7       H      Math
# 8       I      Math

# %%
df = courses.groupby('class')['student'].count().reset_index()
df
# Out:
#       class  student
# 0   Biology        1
# 1  Computer        1
# 2   English        1
# 3      Math        6

# %%
df = df[df['student'] >= 5][['class']]
df
# Out:
#   class
# 3  Math

# %% [markdown]
# #### 586 - Customer Placing the Largest Number of orders
#
# find the customer_number for the customer who has placed the largest number of orders.
#
# The test cases are generated so that exactly one customer will have placed more orders than any other customer.

# %%
data = [[1, 1], [2, 2], [3, 3], [4, 3]]
orders = pd.DataFrame(data, columns=['order_number', 'customer_number']).astype({'order_number':'Int64', 'customer_number':'Int64'})
orders
# Out:
#    order_number  customer_number
# 0             1                1
# 1             2                2
# 2             3                3
# 3             4                3

# %%
df = orders.groupby('customer_number')['order_number'].count().reset_index()
df
# Out:
#    customer_number  order_number
# 0                1             1
# 1                2             1
# 2                3             2

# %%
df = df[df['order_number'] == df['order_number'].max()][['customer_number']]
df
# Out:
#    customer_number
# 2                3

# %% [markdown]
# #### 1484 - Group Sold Products by the Date
#
# find for each date the number of different products sold and their names.
#
# The sold products names for each date should be sorted lexicographically.
#
# Return the result table ordered by sell_date.

# %%
data = [['2020-05-30', 'Headphone'], ['2020-06-01', 'Pencil'], ['2020-06-02', 'Mask'], ['2020-05-30', 'Basketball'], ['2020-06-01', 'Bible'], ['2020-06-02', 'Mask'], ['2020-05-30', 'T-Shirt']]
activities = pd.DataFrame(data, columns=['sell_date', 'product']).astype({'sell_date':'datetime64[ns]', 'product':'object'})
activities
# Out:
#    sell_date     product
# 0 2020-05-30   Headphone
# 1 2020-06-01      Pencil
# 2 2020-06-02        Mask
# 3 2020-05-30  Basketball
# 4 2020-06-01       Bible
# 5 2020-06-02        Mask
# 6 2020-05-30     T-Shirt

# %%
activities = activities.sort_values(by='product')
activities
# Out:
#    sell_date     product
# 3 2020-05-30  Basketball
# 4 2020-06-01       Bible
# 0 2020-05-30   Headphone
# 2 2020-06-02        Mask
# 5 2020-06-02        Mask
# 1 2020-06-01      Pencil
# 6 2020-05-30     T-Shirt

# %%
df = activities.groupby(['sell_date']).agg({'product':['nunique','unique']}).reset_index()
df
# Out:
#    sell_date product
#              nunique                            unique
# 0 2020-05-30       3  [Basketball, Headphone, T-Shirt]
# 1 2020-06-01       2                   [Bible, Pencil]
# 2 2020-06-02       1                            [Mask]

# %%
df.columns = [c[0] + '_' + c[1] for c in df.columns]
df = df.rename(columns={'sell_date':'sell_date','product_nunique':'num_sold','product_unique':'products'})
df
# Out:
#   sell_date_  num_sold                          products
# 0 2020-05-30         3  [Basketball, Headphone, T-Shirt]
# 1 2020-06-01         2                   [Bible, Pencil]
# 2 2020-06-02         1                            [Mask]

# %%
# df['products'] = df['products'].apply(','.join)
df = df.sort_values(by='sell_date_')
df
# Out:
#   sell_date_  num_sold                          products
# 0 2020-05-30         3  [Basketball, Headphone, T-Shirt]
# 1 2020-06-01         2                   [Bible, Pencil]
# 2 2020-06-02         1                            [Mask]

# %% [markdown]
# #### 1693 - Daily Leads and Partners
#
# For each date_id and make_name, find the number of distinct lead_id's and distinct partner_id's.
#
# Return the result table in any order.

# %%
data = [['2020-12-8', 'toyota', 0, 1], ['2020-12-8', 'toyota', 1, 0], ['2020-12-8', 'toyota', 1, 2], ['2020-12-7', 'toyota', 0, 2], ['2020-12-7', 'toyota', 0, 1], ['2020-12-8', 'honda', 1, 2], ['2020-12-8', 'honda', 2, 1], ['2020-12-7', 'honda', 0, 1], ['2020-12-7', 'honda', 1, 2], ['2020-12-7', 'honda', 2, 1]]
daily_sales = pd.DataFrame(data, columns=['date_id', 'make_name', 'lead_id', 'partner_id']).astype({'date_id':'datetime64[ns]', 'make_name':'object', 'lead_id':'Int64', 'partner_id':'Int64'})
daily_sales
# Out:
#      date_id make_name  lead_id  partner_id
# 0 2020-12-08    toyota        0           1
# 1 2020-12-08    toyota        1           0
# 2 2020-12-08    toyota        1           2
# 3 2020-12-07    toyota        0           2
# 4 2020-12-07    toyota        0           1
# 5 2020-12-08     honda        1           2
# 6 2020-12-08     honda        2           1
# 7 2020-12-07     honda        0           1
# 8 2020-12-07     honda        1           2
# 9 2020-12-07     honda        2           1

# %%
df = daily_sales.groupby(['date_id','make_name'])[['lead_id','partner_id']].nunique()
df
# Out:
#                       lead_id  partner_id
# date_id    make_name
# 2020-12-07 honda            3           2
#            toyota           1           2
# 2020-12-08 honda            2           2
#            toyota           2           3

# %%
df = df.reset_index().rename(columns={'lead_id':'unique_leads','partner_id':'unique_partners'})
df
# Out:
#      date_id make_name  unique_leads  unique_partners
# 0 2020-12-07     honda             3                2
# 1 2020-12-07    toyota             1                2
# 2 2020-12-08     honda             2                2
# 3 2020-12-08    toyota             2                3

# %% [markdown]
# ### 1050 - Actors and Directors who cooperated at least three times
#
# find all the pairs (actor_id, director_id) where the actor has cooperated with the director at least three times.
#
# Return the result table in any order.

# %%
data = [[1, 1, 0], [1, 1, 1], [1, 1, 2], [1, 2, 3], [1, 2, 4], [2, 1, 5], [2, 1, 6]]
actor_director = pd.DataFrame(data, columns=['actor_id', 'director_id', 'timestamp']).astype({'actor_id':'int64', 'director_id':'int64', 'timestamp':'int64'})
actor_director
# Out:
#    actor_id  director_id  timestamp
# 0         1            1          0
# 1         1            1          1
# 2         1            1          2
# 3         1            2          3
# 4         1            2          4
# 5         2            1          5
# 6         2            1          6

# %%
df = actor_director[['actor_id','director_id']].value_counts().reset_index()
df
# Out:
#    actor_id  director_id  count
# 0         1            1      3
# 1         1            2      2
# 2         2            1      2

# %%
df = df[df['count'] >= 3]
df
# Out:
#    actor_id  director_id  count
# 0         1            1      3

# %%
df = df[['actor_id','director_id']]
df
# Out:
#    actor_id  director_id
# 0         1            1

# %% [markdown]
# #### 1378 - Replace employee id with the unique identifier
#
# show the unique ID of each user, If a user does not have a unique ID replace just show null.
#
# Return the result table in any order.

# %%
data = [[1, 'Alice'], [7, 'Bob'], [11, 'Meir'], [90, 'Winston'], [3, 'Jonathan']]
employees = pd.DataFrame(data, columns=['id', 'name']).astype({'id':'int64', 'name':'object'})

data = [[3, 1], [11, 2], [90, 3]]
employee_uni = pd.DataFrame(data, columns=['id', 'unique_id']).astype({'id':'int64', 'unique_id':'int64'})

# %%
employees
# Out:
#    id      name
# 0   1     Alice
# 1   7       Bob
# 2  11      Meir
# 3  90   Winston
# 4   3  Jonathan

# %%
employee_uni
# Out:
#    id  unique_id
# 0   3          1
# 1  11          2
# 2  90          3

# %%
df = employees.merge(employee_uni,how='left',on='id')
df
# Out:
#    id      name  unique_id
# 0   1     Alice        NaN
# 1   7       Bob        NaN
# 2  11      Meir        2.0
# 3  90   Winston        3.0
# 4   3  Jonathan        1.0

# %%
df = df[['unique_id','name']]
df
# Out:
#    unique_id      name
# 0        NaN     Alice
# 1        NaN       Bob
# 2        2.0      Meir
# 3        3.0   Winston
# 4        1.0  Jonathan

# %% [markdown]
# #### 1280 - Students and Examinations
#
# find the number of times each student attended each exam.
#
# Return the result table ordered by student_id and subject_name.

# %%
data = [[1, 'Alice'], [2, 'Bob'], [13, 'John'], [6, 'Alex']]
students = pd.DataFrame(data, columns=['student_id', 'student_name']).astype({'student_id':'Int64', 'student_name':'object'})
students
# Out:
#    student_id student_name
# 0           1        Alice
# 1           2          Bob
# 2          13         John
# 3           6         Alex

# %%
data = [['Math'], ['Physics'], ['Programming']]
subjects = pd.DataFrame(data, columns=['subject_name']).astype({'subject_name':'object'})
subjects
# Out:
#   subject_name
# 0         Math
# 1      Physics
# 2  Programming

# %%
data = [[1, 'Math'], [1, 'Physics'], [1, 'Programming'], [2, 'Programming'], [1, 'Physics'], [1, 'Math'], [13, 'Math'], [13, 'Programming'], [13, 'Physics'], [2, 'Math'], [1, 'Math']]
examinations = pd.DataFrame(data, columns=['student_id', 'subject_name']).astype({'student_id':'Int64', 'subject_name':'object'})
examinations
# Out:
#     student_id subject_name
# 0            1         Math
# 1            1      Physics
# 2            1  Programming
# 3            2  Programming
# 4            1      Physics
# 5            1         Math
# 6           13         Math
# 7           13  Programming
# 8           13      Physics
# 9            2         Math
# 10           1         Math

# %%
grouped = examinations.groupby(['student_id','subject_name']).size().reset_index(name='attended_exams')
grouped
# Out:
#    student_id subject_name  attended_exams
# 0           1         Math               3
# 1           1      Physics               2
# 2           1  Programming               1
# 3           2         Math               1
# 4           2  Programming               1
# 5          13         Math               1
# 6          13      Physics               1
# 7          13  Programming               1

# %%
combinations = pd.merge(students, subjects, how='cross')
combinations
# Out:
#     student_id student_name subject_name
# 0            1        Alice         Math
# 1            1        Alice      Physics
# 2            1        Alice  Programming
# 3            2          Bob         Math
# 4            2          Bob      Physics
# 5            2          Bob  Programming
# 6           13         John         Math
# 7           13         John      Physics
# 8           13         John  Programming
# 9            6         Alex         Math
# 10           6         Alex      Physics
# 11           6         Alex  Programming

# %%
df = pd.merge(combinations, grouped, how='left', on=['student_id','subject_name'])
df
# Out:
#     student_id student_name subject_name  attended_exams
# 0            1        Alice         Math             3.0
# 1            1        Alice      Physics             2.0
# 2            1        Alice  Programming             1.0
# 3            2          Bob         Math             1.0
# 4            2          Bob      Physics             NaN
# 5            2          Bob  Programming             1.0
# 6           13         John         Math             1.0
# 7           13         John      Physics             1.0
# 8           13         John  Programming             1.0
# 9            6         Alex         Math             NaN
# 10           6         Alex      Physics             NaN
# 11           6         Alex  Programming             NaN

# %%
df['attended_exams'] = df['attended_exams'].fillna(0)
df.sort_values(['student_id','subject_name'],inplace=True)
df
# Out:
#     student_id student_name subject_name  attended_exams
# 0            1        Alice         Math             3.0
# 1            1        Alice      Physics             2.0
# 2            1        Alice  Programming             1.0
# 3            2          Bob         Math             1.0
# 4            2          Bob      Physics             0.0
# 5            2          Bob  Programming             1.0
# 9            6         Alex         Math             0.0
# 10           6         Alex      Physics             0.0
# 11           6         Alex  Programming             0.0
# 6           13         John         Math             1.0
# 7           13         John      Physics             1.0
# 8           13         John  Programming             1.0

# %%
df.sort_values(['student_id','subject_name'],inplace=True)
df
# Out:
#     student_id student_name subject_name  attended_exams
# 0            1        Alice         Math             3.0
# 1            1        Alice      Physics             2.0
# 2            1        Alice  Programming             1.0
# 3            2          Bob         Math             1.0
# 4            2          Bob      Physics             0.0
# 5            2          Bob  Programming             1.0
# 9            6         Alex         Math             0.0
# 10           6         Alex      Physics             0.0
# 11           6         Alex  Programming             0.0
# 6           13         John         Math             1.0
# 7           13         John      Physics             1.0
# 8           13         John  Programming             1.0

# %% [markdown]
# #### 607 - Sales person
#
# find the names of all the salespersons who did not have any orders related to the company with the name "RED".
#
# Return the result table in any order

# %%
data = [[1, 'John', 100000, 6, '4/1/2006'], [2, 'Amy', 12000, 5, '5/1/2010'], [3, 'Mark', 65000, 12, '12/25/2008'], [4, 'Pam', 25000, 25, '1/1/2005'], [5, 'Alex', 5000, 10, '2/3/2007']]
sales_person = pd.DataFrame(data, columns=['sales_id', 'name', 'salary', 'commission_rate', 'hire_date']).astype({'sales_id':'Int64', 'name':'object', 'salary':'Int64', 'commission_rate':'Int64', 'hire_date':'datetime64[ns]'})

data = [[1, 'RED', 'Boston'], [2, 'ORANGE', 'New York'], [3, 'YELLOW', 'Boston'], [4, 'GREEN', 'Austin']]
company = pd.DataFrame(data, columns=['com_id', 'name', 'city']).astype({'com_id':'Int64', 'name':'object', 'city':'object'})

data = [[1, '1/1/2014', 3, 4, 10000], [2, '2/1/2014', 4, 5, 5000], [3, '3/1/2014', 1, 1, 50000], [4, '4/1/2014', 1, 4, 25000]]
orders = pd.DataFrame(data, columns=['order_id', 'order_date', 'com_id', 'sales_id', 'amount']).astype({'order_id':'Int64', 'order_date':'datetime64[ns]', 'com_id':'Int64', 'sales_id':'Int64', 'amount':'Int64'})

# %%
df = orders.merge(sales_person,how='left',on='sales_id').merge(company,how='left',on='com_id')
df
# Out:
#    order_id order_date  com_id  sales_id  amount name_x  salary  \
# 0         1 2014-01-01       3         4   10000    Pam   25000
# 1         2 2014-02-01       4         5    5000   Alex    5000
# 2         3 2014-03-01       1         1   50000   John  100000
# 3         4 2014-04-01       1         4   25000    Pam   25000
#
#    commission_rate  hire_date  name_y    city
# 0               25 2005-01-01  YELLOW  Boston
# 1               10 2007-02-03   GREEN  Austin
# 2                6 2006-04-01     RED  Boston
# 3               25 2005-01-01     RED  Boston

# %%
# separate company ids for 'red' companies
red_code = company[company['name'] == 'RED']['com_id']
red_code
# Out:
# 0    1
# Name: com_id, dtype: Int64

# %%
#separate sales ids for red companies
red_sales = orders[orders['com_id'].isin(red_code)]['sales_id']
red_sales
# Out:
# 2    1
# 3    4
# Name: sales_id, dtype: Int64

# %%
non_red_sales = sales_person[~sales_person['sales_id'].isin(red_sales)][['name']]
non_red_sales
# Out:
#    name
# 1   Amy
# 2  Mark
# 4  Alex

# %% [markdown]
# #### 570. Managers with at Least 5 Direct Reports
#
# find managers with at least five direct reports.
#
# Return the result table in any order.

# %%
data = [[101, 'John', 'A', None], [102, 'Dan', 'A', 101], [103, 'James', 'A', 101], [104, 'Amy', 'A', 101], [105, 'Anne', 'A', 101], [106, 'Ron', 'B', 101]]
employee = pd.DataFrame(data, columns=['id', 'name', 'department', 'managerId']).astype({'id':'Int64', 'name':'object', 'department':'object', 'managerId':'Int64'})

employee
# Out:
#     id   name department  managerId
# 0  101   John          A       <NA>
# 1  102    Dan          A        101
# 2  103  James          A        101
# 3  104    Amy          A        101
# 4  105   Anne          A        101
# 5  106    Ron          B        101

# %%
manager_count = employee['managerId'].value_counts()
manager_count
# Out:
# managerId
# 101    5
# Name: count, dtype: Int64

# %%
five_report = manager_count[manager_count >= 5]
five_report
# Out:
# managerId
# 101    5
# Name: count, dtype: Int64

# %%
result = employee[employee['id'].isin(five_report.index)][['name']]
result
# Out:
#    name
# 0  John

# %% [markdown]
# ##### 175 - Combine Two Tables
#
# Write a solution to report the first name, last name, city, and state of each person in the Person table. If the address of a personId is not present in the Address table, report null instead.
#
# Return the result table in any order.

# %%
data = [[1, 'Wang', 'Allen'], [2, 'Alice', 'Bob']]
person = pd.DataFrame(data, columns=['personId', 'firstName', 'lastName']).astype({'personId':'Int64', 'firstName':'object', 'lastName':'object'})
person
# Out:
#    personId firstName lastName
# 0         1      Wang    Allen
# 1         2     Alice      Bob

# %%
data = [[1, 2, 'New York City', 'New York'], [2, 3, 'Leetcode', 'California']]
address = pd.DataFrame(data, columns=['addressId', 'personId', 'city', 'state']).astype({'addressId':'Int64', 'personId':'Int64', 'city':'object', 'state':'object'})
address
# Out:
#    addressId  personId           city       state
# 0          1         2  New York City    New York
# 1          2         3       Leetcode  California

# %%
df = pd.merge(person, address, how='left', on='personId')
df
# Out:
#    personId firstName lastName  addressId           city     state
# 0         1      Wang    Allen       <NA>            NaN       NaN
# 1         2     Alice      Bob          1  New York City  New York

# %%
df[['firstName','lastName','city','state']]
# Out:
#   firstName lastName           city     state
# 0      Wang    Allen            NaN       NaN
# 1     Alice      Bob  New York City  New York

# %% [markdown]
# ##### 181 - Employees earning more than their Managers
#
# Write a solution to find the employees who earn more than their managers.
# Return the result table in any order.

# %%
data = [[1, 'Joe', 70000, 3], [2, 'Henry', 80000, 4], [3, 'Sam', 60000, None], [4, 'Max', 90000, None]]
employee = pd.DataFrame(data, columns=['id', 'name', 'salary', 'managerId']).astype({'id':'Int64', 'name':'object', 'salary':'Int64', 'managerId':'Int64'})

employee
# Out:
#    id   name  salary  managerId
# 0   1    Joe   70000          3
# 1   2  Henry   80000          4
# 2   3    Sam   60000       <NA>
# 3   4    Max   90000       <NA>

# %%
df = employee.merge(employee, left_on='managerId', right_on='id', suffixes=('','_Manager'))
df
# Out:
#    id   name  salary  managerId  id_Manager name_Manager  salary_Manager  \
# 0   1    Joe   70000          3           3          Sam           60000
# 1   2  Henry   80000          4           4          Max           90000
#
#    managerId_Manager
# 0               <NA>
# 1               <NA>

# %%
# filter employees whose salary is greater than their manager'
result = df[df['salary'] > df['salary_Manager']]
result
# Out:
#    id name  salary  managerId  id_Manager name_Manager  salary_Manager  \
# 0   1  Joe   70000          3           3          Sam           60000
#
#    managerId_Manager
# 0               <NA>

# %%
result[['name']].rename(columns={'name':'Employee'})
# Out:
#   Employee
# 0      Joe

# %% [markdown]
# ##### 1890 - Latest Login in 2020
#
# Write a solution to report the latest login for all users in the year 2020. Do not include the users who did not login in 2020.
# Return the result table in any order.

# %%
data = [[6, '2020-06-30 15:06:07'], [6, '2021-04-21 14:06:06'], [6, '2019-03-07 00:18:15'], [8, '2020-02-01 05:10:53'], [8, '2020-12-30 00:46:50'], [2, '2020-01-16 02:49:50'], [2, '2019-08-25 07:59:08'], [14, '2019-07-14 09:00:00'], [14, '2021-01-06 11:59:59']]
logins = pd.DataFrame(data, columns=['user_id', 'time_stamp']).astype({'user_id':'Int64', 'time_stamp':'datetime64[ns]'})
logins
# Out:
#    user_id          time_stamp
# 0        6 2020-06-30 15:06:07
# 1        6 2021-04-21 14:06:06
# 2        6 2019-03-07 00:18:15
# 3        8 2020-02-01 05:10:53
# 4        8 2020-12-30 00:46:50
# 5        2 2020-01-16 02:49:50
# 6        2 2019-08-25 07:59:08
# 7       14 2019-07-14 09:00:00
# 8       14 2021-01-06 11:59:59

# %%
logins['time_stamp'] = pd.to_datetime(logins['time_stamp'])
logins['time_stamp']
# Out:
# 0   2020-06-30 15:06:07
# 1   2021-04-21 14:06:06
# 2   2019-03-07 00:18:15
# 3   2020-02-01 05:10:53
# 4   2020-12-30 00:46:50
# 5   2020-01-16 02:49:50
# 6   2019-08-25 07:59:08
# 7   2019-07-14 09:00:00
# 8   2021-01-06 11:59:59
# Name: time_stamp, dtype: datetime64[ns]

# %%
df_2020 = logins[logins['time_stamp'].dt.year == 2020]
df_2020
# Out:
#    user_id          time_stamp
# 0        6 2020-06-30 15:06:07
# 3        8 2020-02-01 05:10:53
# 4        8 2020-12-30 00:46:50
# 5        2 2020-01-16 02:49:50

# %%
latest_logins = df_2020.groupby('user_id')['time_stamp'].max().reset_index()
latest_logins
# Out:
#    user_id          time_stamp
# 0        2 2020-01-16 02:49:50
# 1        6 2020-06-30 15:06:07
# 2        8 2020-12-30 00:46:50

# %%
latest_logins = latest_logins.rename(columns={'time_stamp': 'last_stamp'})
latest_logins
# Out:
#    user_id          last_stamp
# 0        2 2020-01-16 02:49:50
# 1        6 2020-06-30 15:06:07
# 2        8 2020-12-30 00:46:50

# %% [markdown]
# ##### 1965 - Employees with missing information
#
# Write a solution to report the IDs of all the employees with missing information. The information of an employee is missing if:
#
# The employee's name is missing, or
# The employee's salary is missing.
# Return the result table ordered by employee_id in ascending order.

# %%
data = [[2, 'Crew'], [4, 'Haven'], [5, 'Kristian']]
employees = pd.DataFrame(data, columns=['employee_id', 'name']).astype({'employee_id':'Int64', 'name':'object'})

data = [[5, 76071], [1, 22517], [4, 63539]]
salaries = pd.DataFrame(data, columns=['employee_id', 'salary']).astype({'employee_id':'Int64', 'salary':'Int64'})

# %%
employees
# Out:
#    employee_id      name
# 0            2      Crew
# 1            4     Haven
# 2            5  Kristian

# %%
salaries
# Out:
#    employee_id  salary
# 0            5   76071
# 1            1   22517
# 2            4   63539

# %%
df = employees.merge(salaries, how='outer', on='employee_id')
df
# Out:
#    employee_id      name  salary
# 0            1       NaN   22517
# 1            2      Crew    <NA>
# 2            4     Haven   63539
# 3            5  Kristian   76071

# %%
missing_info = df[df['name'].isnull() | df['salary'].isnull()]
missing_info
# Out:
#    employee_id  name  salary
# 0            1   NaN   22517
# 1            2  Crew    <NA>

# %%
result = missing_info[['employee_id']].sort_values(by='employee_id').reset_index(drop=True)
result
# Out:
#    employee_id
# 0            1
# 1            2

# %% [markdown]
# ##### 3436 - Find Valid Emails
#
# Write a solution to find all the valid email addresses. A valid email address meets the following criteria:
#
# It contains exactly one @ symbol.
# It ends with .com.
# The part before the @ symbol contains only alphanumeric characters and underscores.
# The part after the @ symbol and before .com contains a domain name that contains only letters.
# Return the result table ordered by user_id in ascending order.

# %%
data = [[1, 'alice@example.com'], [2, 'bob_at_example.com'], [3, 'charlie@example.net'], [4, 'david@domain.com'], [5, 'eve@invalid']]
users = pd.DataFrame(data,columns=["user_id", "email"]).astype({"user_id": "int32", "email": "string"})

# %%
users
# Out:
#    user_id                email
# 0        1    alice@example.com
# 1        2   bob_at_example.com
# 2        3  charlie@example.net
# 3        4     david@domain.com
# 4        5          eve@invalid

# %%
import re

# %% [markdown]
# re.compile() is a function from Python’s built-in re (regular expression) module.
# It compiles a regular expression pattern into a regular expression object.

# %%
pattern = re.compile(r'^[a-zA-Z0-9_]+@[a-zA-Z]+\.com$')

# %%
valid = users[users['email'].apply(lambda x: bool(pattern.match(x)))]
valid
# Out:
#    user_id              email
# 0        1  alice@example.com
# 3        4   david@domain.com

# %%
sorted = valid.sort_values(by='user_id')
sorted
# Out:
#    user_id              email
# 0        1  alice@example.com
# 3        4   david@domain.com

# %% [markdown]
# ##### 3465 - Find Products with Valid Serial Numbers
#
# Write a solution to find all products whose description contains a valid serial number pattern. A valid serial number follows these rules:
#
# It starts with the letters SN (case-sensitive).
# Followed by exactly 4 digits.
# It must have a hyphen (-) followed by exactly 4 digits.
# The serial number must be within the description (it may not necessarily start at the beginning).
# Return the result table ordered by product_id in ascending order.

# %%
data = [[1, 'Widget A', 'This is a sample product with SN1234-5678'], [2, 'Widget B', 'A product with serial SN9876-1234 in the description'], [3, 'Widget C', 'Product SN1234-56789 is available now'], [4, 'Widget D', 'No serial number here'], [5, 'Widget E', 'Check out SN4321-8765 in this description']]
products = pd.DataFrame(data,columns=['product_id', 'product_name', 'description']).astype({'product_id': 'int32', 'product_name': 'string', 'description': 'string'})
products
# Out:
#    product_id product_name                                        description
# 0           1     Widget A          This is a sample product with SN1234-5678
# 1           2     Widget B  A product with serial SN9876-1234 in the descr...
# 2           3     Widget C              Product SN1234-56789 is available now
# 3           4     Widget D                              No serial number here
# 4           5     Widget E          Check out SN4321-8765 in this description

# %%
pattern = r'\bSN\d{4}-\d{4}\b'

# %% [markdown]
# /b - make sure its not longer word like ASN or any other
# SN - Exactly these letters at starting
# \d{4} - exactly 4 digits
# \b - must stop after last digit

# %%
filter_data = products[products['description'].str.contains(pattern, regex=True)]
filter_data
# Out:
#    product_id product_name                                        description
# 0           1     Widget A          This is a sample product with SN1234-5678
# 1           2     Widget B  A product with serial SN9876-1234 in the descr...
# 4           5     Widget E          Check out SN4321-8765 in this description

# %% [markdown]
# ##### 3570 - Find Books with No Available Copies
#
# Write a solution to find all books that are currently borrowed (not returned) and have zero copies available in the library.
#
# A book is considered currently borrowed if there exists a borrowing record with a NULL return_date
# Return the result table ordered by current borrowers in descending order, then by book title in ascending order.

# %%
data = [[1, 'The Great Gatsby', 'F. Scott', 'Fiction', 1925, 3], [2, 'To Kill a Mockingbird', 'Harper Lee', 'Fiction', 1960, 3], [3, '1984', 'George Orwell', 'Dystopian', 1949, 1], [4, 'Pride and Prejudice', 'Jane Austen', 'Romance', 1813, 2], [5, 'The Catcher in the Rye', 'J.D. Salinger', 'Fiction', 1951, 1], [6, 'Brave New World', 'Aldous Huxley', 'Dystopian', 1932, 4]]
library_books = pd.DataFrame(data,columns={
    'book_id': pd.Series(dtype='int'),
    'title': pd.Series(dtype='str'),
    'author': pd.Series(dtype='str'),
    'genre': pd.Series(dtype='str'),
    'publication_year': pd.Series(dtype='int'),
    'total_copies': pd.Series(dtype='int')
})
library_books
# Out:
#    book_id                   title         author      genre  \
# 0        1        The Great Gatsby       F. Scott    Fiction
# 1        2   To Kill a Mockingbird     Harper Lee    Fiction
# 2        3                    1984  George Orwell  Dystopian
# 3        4     Pride and Prejudice    Jane Austen    Romance
# 4        5  The Catcher in the Rye  J.D. Salinger    Fiction
# 5        6         Brave New World  Aldous Huxley  Dystopian
#
#    publication_year  total_copies
# 0              1925             3
# 1              1960             3
# 2              1949             1
# 3              1813             2
# 4              1951             1
# 5              1932             4

# %%
data = [[1, 1, 'Alice Smith', '2024-01-15', None], [2, 1, 'Bob Johnson', '2024-01-20', None], [3, 2, 'Carol White', '2024-01-10', '2024-01-25'], [4, 3, 'David Brown', '2024-02-01', None], [5, 4, 'Emma Wilson', '2024-01-05', None], [6, 5, 'Frank Davis', '2024-01-18', '2024-02-10'], [7, 1, 'Grace Miller', '2024-02-05', None], [8, 6, 'Henry Taylor', '2024-01-12', None], [9, 2, 'Ivan Clark', '2024-02-12', None], [10, 2, 'Jane Adams', '2024-02-15', None]]
borrowing_records = pd.DataFrame(data,columns={
    'record_id': pd.Series(dtype='int'),
    'book_id': pd.Series(dtype='int'),
    'borrower_name': pd.Series(dtype='str'),
    'borrow_date': pd.Series(dtype='datetime64[ns]'),
    'return_date': pd.Series(dtype='datetime64[ns]')
})
borrowing_records
# Out:
#    record_id  book_id borrower_name borrow_date return_date
# 0          1        1   Alice Smith  2024-01-15        None
# 1          2        1   Bob Johnson  2024-01-20        None
# 2          3        2   Carol White  2024-01-10  2024-01-25
# 3          4        3   David Brown  2024-02-01        None
# 4          5        4   Emma Wilson  2024-01-05        None
# 5          6        5   Frank Davis  2024-01-18  2024-02-10
# 6          7        1  Grace Miller  2024-02-05        None
# 7          8        6  Henry Taylor  2024-01-12        None
# 8          9        2    Ivan Clark  2024-02-12        None
# 9         10        2    Jane Adams  2024-02-15        None

# %%
# Return_Date is null
currently_borrowed = borrowing_records[borrowing_records['return_date'].isna()]
currently_borrowed
# Out:
#    record_id  book_id borrower_name borrow_date return_date
# 0          1        1   Alice Smith  2024-01-15        None
# 1          2        1   Bob Johnson  2024-01-20        None
# 3          4        3   David Brown  2024-02-01        None
# 4          5        4   Emma Wilson  2024-01-05        None
# 6          7        1  Grace Miller  2024-02-05        None
# 7          8        6  Henry Taylor  2024-01-12        None
# 8          9        2    Ivan Clark  2024-02-12        None
# 9         10        2    Jane Adams  2024-02-15        None

# %%
# Counting current borrowing per book
borrow_counts = currently_borrowed.groupby('book_id')['borrower_name'].count().reset_index()
borrow_counts
# Out:
#    book_id  borrower_name
# 0        1              3
# 1        2              2
# 2        3              1
# 3        4              1
# 4        6              1

# %%
# renaming column name
borrow_counts.rename(columns={'borrower_name': 'current_borrowers'}, inplace=True)
borrow_counts
# Out:
#    book_id  current_borrowers
# 0        1                  3
# 1        2                  2
# 2        3                  1
# 3        4                  1
# 4        6                  1

# %%
# Merging table to get total copies
merged = pd.merge(library_books, borrow_counts, on='book_id')
merged
# Out:
#    book_id                  title         author      genre  publication_year  \
# 0        1       The Great Gatsby       F. Scott    Fiction              1925
# 1        2  To Kill a Mockingbird     Harper Lee    Fiction              1960
# 2        3                   1984  George Orwell  Dystopian              1949
# 3        4    Pride and Prejudice    Jane Austen    Romance              1813
# 4        6        Brave New World  Aldous Huxley  Dystopian              1932
#
#    total_copies  current_borrowers
# 0             3                  3
# 1             3                  2
# 2             1                  1
# 3             2                  1
# 4             4                  1

# %%
# All copies are borrowed (tptal_copies - current_borrowers)
fully_borrowed_books = merged[merged['total_copies'] == merged['current_borrowers']]
fully_borrowed_books
# Out:
#    book_id             title         author      genre  publication_year  \
# 0        1  The Great Gatsby       F. Scott    Fiction              1925
# 2        3              1984  George Orwell  Dystopian              1949
#
#    total_copies  current_borrowers
# 0             3                  3
# 2             1                  1

# %%
# Sorting by question
result = fully_borrowed_books.sort_values(by=['current_borrowers','title'],ascending=[False, True])
result
# Out:
#    book_id             title         author      genre  publication_year  \
# 0        1  The Great Gatsby       F. Scott    Fiction              1925
# 2        3              1984  George Orwell  Dystopian              1949
#
#    total_copies  current_borrowers
# 0             3                  3
# 2             1                  1

# %% [markdown]
# ##### 1158 - Market Analysis - I
#
# Write a solution to find for each user, the join date and the number of orders they made as a buyer in 2019.
#
# Return the result table in any order.

# %%
data = [[1, '2018-01-01', 'Lenovo'], [2, '2018-02-09', 'Samsung'], [3, '2018-01-19', 'LG'], [4, '2018-05-21', 'HP']]
users = pd.DataFrame(data, columns=['user_id', 'join_date', 'favorite_brand']).astype({'user_id':'Int64', 'join_date':'datetime64[ns]', 'favorite_brand':'object'})
users
# Out:
#    user_id  join_date favorite_brand
# 0        1 2018-01-01         Lenovo
# 1        2 2018-02-09        Samsung
# 2        3 2018-01-19             LG
# 3        4 2018-05-21             HP

# %%
data = [[1, '2019-08-01', 4, 1, 2], [2, '2018-08-02', 2, 1, 3], [3, '2019-08-03', 3, 2, 3], [4, '2018-08-04', 1, 4, 2], [5, '2018-08-04', 1, 3, 4], [6, '2019-08-05', 2, 2, 4]]
orders = pd.DataFrame(data, columns=['order_id', 'order_date', 'item_id', 'buyer_id', 'seller_id']).astype({'order_id':'Int64', 'order_date':'datetime64[ns]', 'item_id':'Int64', 'buyer_id':'Int64', 'seller_id':'Int64'})
orders
# Out:
#    order_id order_date  item_id  buyer_id  seller_id
# 0         1 2019-08-01        4         1          2
# 1         2 2018-08-02        2         1          3
# 2         3 2019-08-03        3         2          3
# 3         4 2018-08-04        1         4          2
# 4         5 2018-08-04        1         3          4
# 5         6 2019-08-05        2         2          4

# %%
data = [[1, 'Samsung'], [2, 'Lenovo'], [3, 'LG'], [4, 'HP']]
items = pd.DataFrame(data, columns=['item_id', 'item_brand']).astype({'item_id':'Int64', 'item_brand':'object'})
items
# Out:
#    item_id item_brand
# 0        1    Samsung
# 1        2     Lenovo
# 2        3         LG
# 3        4         HP

# %%
# Convert date to datetime
users['join_date'] = pd.to_datetime(users['join_date'])
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
users['join_date']
# Out:
# 0   2018-01-01
# 1   2018-02-09
# 2   2018-01-19
# 3   2018-05-21
# Name: join_date, dtype: datetime64[ns]

# %%
orders['order_date']
# Out:
# 0   2019-08-01
# 1   2018-08-02
# 2   2019-08-03
# 3   2018-08-04
# 4   2018-08-04
# 5   2019-08-05
# Name: order_date, dtype: datetime64[ns]

# %%
# Filter orders by 2019
orders_2019 = orders[orders['order_date'].dt.year == 2019]
orders_2019
# Out:
#    order_id order_date  item_id  buyer_id  seller_id
# 0         1 2019-08-01        4         1          2
# 2         3 2019-08-03        3         2          3
# 5         6 2019-08-05        2         2          4

# %%
# count orders per user(buyer) in 2019
order_counts = orders_2019.groupby('buyer_id').size().reset_index(name='orders_2019')
order_counts
# Out:
#    buyer_id  orders_2019
# 0         1            1
# 1         2            2

# %%
# merge users to get join_date and all users are included
result = pd.merge(users, order_counts, how='left', left_on='user_id', right_on='buyer_id')
result
# Out:
#    user_id  join_date favorite_brand  buyer_id  orders_2019
# 0        1 2018-01-01         Lenovo         1          1.0
# 1        2 2018-02-09        Samsung         2          2.0
# 2        3 2018-01-19             LG      <NA>          NaN
# 3        4 2018-05-21             HP      <NA>          NaN

# %%
# fill nan values with 0 and drop redundant buyer_id column
result['orders_2019'] = result['orders_2019'].fillna(0)
result = result[['user_id', 'join_date','orders_2019']]
result
# Out:
#    user_id  join_date  orders_2019
# 0        1 2018-01-01            1
# 1        2 2018-02-09            2
# 2        3 2018-01-19            0
# 3        4 2018-05-21            0

# %% [markdown]
# ##### 608 - Tree Node
#
# Each node in the tree can be one of three types:
#
# "Leaf": if the node is a leaf node.
# "Root": if the node is the root of the tree.
# "Inner": If the node is neither a leaf node nor a root node.
# Write a solution to report the type of each node in the tree.
#
# Return the result table in any order.

# %%
data = [[1, None], [2, 1], [3, 1], [4, 2], [5, 2]]
tree = pd.DataFrame(data, columns=['id', 'p_id']).astype({'id':'Int64', 'p_id':'Int64'})
tree
# Out:
#    id  p_id
# 0   1  <NA>
# 1   2     1
# 2   3     1
# 3   4     2
# 4   5     2

# %%
# set parent id 
parent_id = set(tree['p_id'].dropna())

# %%
# classify each node
def classify(row):
    if pd.isna(row['p_id']):
        return 'Root'
    elif row['id'] in parent_id:
        return 'Inner'
    else:
        return 'Leaf'

# %%
tree['type'] = tree.apply(classify, axis=1)
tree
# Out:
#    id  p_id   type
# 0   1  <NA>   Root
# 1   2     1  Inner
# 2   3     1   Leaf
# 3   4     2   Leaf
# 4   5     2   Leaf

# %% [markdown]
# ##### 3421 - Find students who improved in subject
#
# Write a solution to find the students who have shown improvement.
#
# A student is considered to have shown improvement if they meet both of these conditions:
#
# Have taken exams in the same subject on at least two different dates
#
# Their latest score in that subject is higher than their first score
#
# Return the result table ordered by student_id, subject in ascending order.

# %%
data = [[101, 'Math', 70, '2023-01-15'], [101, 'Math', 85, '2023-02-15'], [101, 'Physics', 65, '2023-01-15'], [101, 'Physics', 60, '2023-02-15'], [102, 'Math', 80, '2023-01-15'], [102, 'Math', 85, '2023-02-15'], [103, 'Math', 90, '2023-01-15'], [104, 'Physics', 75, '2023-01-15'], [104, 'Physics', 85, '2023-02-15']]
scores = pd.DataFrame(data,columns={"student_id": pd.Series(dtype="int"),
                          "subject": pd.Series(dtype="str"),
                          "score": pd.Series(dtype="int"),
                          "exam_date": pd.Series(dtype="str")})
scores
# Out:
#    student_id  subject  score   exam_date
# 0         101     Math     70  2023-01-15
# 1         101     Math     85  2023-02-15
# 2         101  Physics     65  2023-01-15
# 3         101  Physics     60  2023-02-15
# 4         102     Math     80  2023-01-15
# 5         102     Math     85  2023-02-15
# 6         103     Math     90  2023-01-15
# 7         104  Physics     75  2023-01-15
# 8         104  Physics     85  2023-02-15

# %%
# sort by exam date
scores = scores.sort_values(by=['student_id', 'subject', 'exam_date'])
scores
# Out:
#    student_id  subject  score   exam_date
# 0         101     Math     70  2023-01-15
# 1         101     Math     85  2023-02-15
# 2         101  Physics     65  2023-01-15
# 3         101  Physics     60  2023-02-15
# 4         102     Math     80  2023-01-15
# 5         102     Math     85  2023-02-15
# 6         103     Math     90  2023-01-15
# 7         104  Physics     75  2023-01-15
# 8         104  Physics     85  2023-02-15

# %%
# group by student and subject
grouped = scores.groupby(['student_id','subject'])

# %%
# first score
first_scores = grouped.first().reset_index()[['student_id', 'subject', 'score']].rename(columns={'score': 'first_score'})
first_scores
# Out:
#    student_id  subject  first_score
# 0         101     Math           70
# 1         101  Physics           65
# 2         102     Math           80
# 3         103     Math           90
# 4         104  Physics           75

# %%
# last score
latest_scores = grouped.last().reset_index()[['student_id', 'subject', 'score']].rename(columns={'score': 'latest_score'})
latest_scores
# Out:
#    student_id  subject  latest_score
# 0         101     Math            85
# 1         101  Physics            60
# 2         102     Math            85
# 3         103     Math            90
# 4         104  Physics            85

# %%
# merging
df = pd.merge(first_scores, latest_scores, on =['student_id', 'subject'])
df
# Out:
#    student_id  subject  first_score  latest_score
# 0         101     Math           70            85
# 1         101  Physics           65            60
# 2         102     Math           80            85
# 3         103     Math           90            90
# 4         104  Physics           75            85

# %%
# latest > first
result = df[df['latest_score'] > df['first_score']]
result
# Out:
#    student_id  subject  first_score  latest_score
# 0         101     Math           70            85
# 2         102     Math           80            85
# 4         104  Physics           75            85

# %%
result = result.sort_values(by=['student_id', 'subject']).reset_index(drop=True)
result
# Out:
#    student_id  subject  first_score  latest_score
# 0         101     Math           70            85
# 1         102     Math           80            85
# 2         104  Physics           75            85

# %% [markdown]
# #### 620 - Not boring movies
#
# Write a solution to report the movies with an odd-numbered ID and a description that is not "boring".
#
# Return the result table ordered by rating in descending order.

# %%
data = [[1, 'War', 'great 3D', 8.9], [2, 'Science', 'fiction', 8.5], [3, 'irish', 'boring', 6.2], [4, 'Ice song', 'Fantacy', 8.6], [5, 'House card', 'Interesting', 9.1]]
cinema = pd.DataFrame(data, columns=['id', 'movie', 'description', 'rating']).astype({'id':'Int64', 'movie':'object', 'description':'object', 'rating':'Float64'})
cinema
# Out:
#    id       movie  description  rating
# 0   1         War     great 3D     8.9
# 1   2     Science      fiction     8.5
# 2   3       irish       boring     6.2
# 3   4    Ice song      Fantacy     8.6
# 4   5  House card  Interesting     9.1

# %%
df = cinema[cinema['id'] % 2 != 0]
df
# Out:
#    id       movie  description  rating
# 0   1         War     great 3D     8.9
# 2   3       irish       boring     6.2
# 4   5  House card  Interesting     9.1

# %%
result = df[df['description'] != 'boring']
result
# Out:
#    id       movie  description  rating
# 0   1         War     great 3D     8.9
# 4   5  House card  Interesting     9.1

# %%
result.sort_values(by=['rating'], ascending=False)
# Out:
#    id       movie  description  rating
# 4   5  House card  Interesting     9.1
# 0   1         War     great 3D     8.9

# %% [markdown]
# #### 1251 - Average Selling Price
#
# Write a solution to find the average selling price for each product. average_price should be rounded to 2 decimal places. If a product does not have any sold units, its average selling price is assumed to be 0.
#
# Return the result table in any order.

# %%
data = [[1, '2019-02-17', '2019-02-28', 5], [1, '2019-03-01', '2019-03-22', 20], [2, '2019-02-01', '2019-02-20', 15], [2, '2019-02-21', '2019-03-31', 30]]
prices = pd.DataFrame(data, columns=['product_id', 'start_date', 'end_date', 'price']).astype({'product_id':'Int64', 'start_date':'datetime64[ns]', 'end_date':'datetime64[ns]', 'price':'Int64'})
prices
# Out:
#    product_id start_date   end_date  price
# 0           1 2019-02-17 2019-02-28      5
# 1           1 2019-03-01 2019-03-22     20
# 2           2 2019-02-01 2019-02-20     15
# 3           2 2019-02-21 2019-03-31     30

# %%
data = [[1, '2019-02-25', 100], [1, '2019-03-01', 15], [2, '2019-02-10', 200], [2, '2019-03-22', 30]]
units_sold = pd.DataFrame(data, columns=['product_id', 'purchase_date', 'units']).astype({'product_id':'Int64', 'purchase_date':'datetime64[ns]', 'units':'Int64'})
units_sold
# Out:
#    product_id purchase_date  units
# 0           1    2019-02-25    100
# 1           1    2019-03-01     15
# 2           2    2019-02-10    200
# 3           2    2019-03-22     30

# %%
df = pd.merge(prices,units_sold, on='product_id', how='left')
df
# Out:
#    product_id start_date   end_date  price purchase_date  units
# 0           1 2019-02-17 2019-02-28      5    2019-02-25    100
# 1           1 2019-02-17 2019-02-28      5    2019-03-01     15
# 2           1 2019-03-01 2019-03-22     20    2019-02-25    100
# 3           1 2019-03-01 2019-03-22     20    2019-03-01     15
# 4           2 2019-02-01 2019-02-20     15    2019-02-10    200
# 5           2 2019-02-01 2019-02-20     15    2019-03-22     30
# 6           2 2019-02-21 2019-03-31     30    2019-02-10    200
# 7           2 2019-02-21 2019-03-31     30    2019-03-22     30

# %%
df = df[df['purchase_date'].between(df['start_date'], df['end_date'])]
df
# Out:
#    product_id start_date   end_date  price purchase_date  units
# 0           1 2019-02-17 2019-02-28      5    2019-02-25    100
# 3           1 2019-03-01 2019-03-22     20    2019-03-01     15
# 4           2 2019-02-01 2019-02-20     15    2019-02-10    200
# 7           2 2019-02-21 2019-03-31     30    2019-03-22     30

# %% [markdown]
# 1. Filter only valid sales with matching price periods
# 2. Avoid using prices that were not valid on the purchase date
# 3. Ensure accurate calculation of average selling price

# %%
df.loc[:,'income'] = df['price'] * df['units']

# %%
agg_df = df.groupby(['product_id']).sum({'income':'sum'}).reset_index()
agg_df
# Out:
#    product_id  price  units  income
# 0           1     25    115     800
# 1           2     45    230    3900

# %%
agg_df['average_price'] = (agg_df['income'] / agg_df['units']).round(2)
agg_df
# Out:
#    product_id  price  units  income  average_price
# 0           1     25    115     800           6.96
# 1           2     45    230    3900          16.96

# %% [markdown]
# #### 1075 - Project Employee I
#
# Write an SQL query that reports the average experience years of all the employees for each project, rounded to 2 digits.
#
# Return the result table in any order.

# %%
data = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 4]]
project = pd.DataFrame(data, columns=['project_id', 'employee_id']).astype({'project_id':'Int64', 'employee_id':'Int64'})
project
# Out:
#    project_id  employee_id
# 0           1            1
# 1           1            2
# 2           1            3
# 3           2            1
# 4           2            4

# %%
data = [[1, 'Khaled', 3], [2, 'Ali', 2], [3, 'John', 1], [4, 'Doe', 2]]
employee = pd.DataFrame(data, columns=['employee_id', 'name', 'experience_years']).astype({'employee_id':'Int64', 'name':'object', 'experience_years':'Int64'})
employee
# Out:
#    employee_id    name  experience_years
# 0            1  Khaled                 3
# 1            2     Ali                 2
# 2            3    John                 1
# 3            4     Doe                 2

# %%
df = pd.merge(project, employee, on='employee_id')
df
# Out:
#    project_id  employee_id    name  experience_years
# 0           1            1  Khaled                 3
# 1           1            2     Ali                 2
# 2           1            3    John                 1
# 3           2            1  Khaled                 3
# 4           2            4     Doe                 2

# %%
df = df.groupby('project_id')['experience_years'].mean().round(2).reset_index(name='average_years')
df
# Out:
#    project_id  average_years
# 0           1            2.0
# 1           2            2.5

# %% [markdown]
# #### 1633 - Percentage of Users Attended a Contest
#
# Write a solution to find the percentage of the users registered in each contest rounded to two decimals.
#
# Return the result table ordered by percentage in descending order. In case of a tie, order it by contest_id in ascending order.

# %%
data = [[6, 'Alice'], [2, 'Bob'], [7, 'Alex']]
users = pd.DataFrame(data, columns=['user_id', 'user_name']).astype({'user_id':'Int64', 'user_name':'object'})
users
# Out:
#    user_id user_name
# 0        6     Alice
# 1        2       Bob
# 2        7      Alex

# %%
data = [[215, 6], [209, 2], [208, 2], [210, 6], [208, 6], [209, 7], [209, 6], [215, 7], [208, 7], [210, 2], [207, 2], [210, 7]]
register = pd.DataFrame(data, columns=['contest_id', 'user_id']).astype({'contest_id':'Int64', 'user_id':'Int64'})
register
# Out:
#     contest_id  user_id
# 0          215        6
# 1          209        2
# 2          208        2
# 3          210        6
# 4          208        6
# 5          209        7
# 6          209        6
# 7          215        7
# 8          208        7
# 9          210        2
# 10         207        2
# 11         210        7

# %%
df = pd.merge(register, users, on='user_id')
df
# Out:
#     contest_id  user_id user_name
# 0          215        6     Alice
# 1          209        2       Bob
# 2          208        2       Bob
# 3          210        6     Alice
# 4          208        6     Alice
# 5          209        7      Alex
# 6          209        6     Alice
# 7          215        7      Alex
# 8          208        7      Alex
# 9          210        2       Bob
# 10         207        2       Bob
# 11         210        7      Alex

# %%
df['contest_id'].unique()
# Out:
# <IntegerArray>
# [215, 209, 208, 210, 207]
# Length: 5, dtype: Int64

# %%
tot_users = df['user_id'].nunique()
tot_users
# Out:
# 3

# %%
tot_contest = df.groupby('contest_id')['user_id'].nunique().reset_index()
tot_contest
# Out:
#    contest_id  user_id
# 0         207        1
# 1         208        3
# 2         209        3
# 3         210        3
# 4         215        2

# %%
tot_contest['percentage'] = round((tot_contest['user_id'] * 100) / tot_users, 2)
tot_contest
# Out:
#    contest_id  user_id  percentage
# 0         207        1       33.33
# 1         208        3      100.00
# 2         209        3      100.00
# 3         210        3      100.00
# 4         215        2       66.67

# %%
result = tot_contest.sort_values(by=['percentage','contest_id'], ascending=[False, True])
result
# Out:
#    contest_id  user_id  percentage
# 1         208        3      100.00
# 2         209        3      100.00
# 3         210        3      100.00
# 4         215        2       66.67
# 0         207        1       33.33

# %% [markdown]
# #### 1211 - Queries Quality and Percentage
#
# We define query quality as:
#
# The average of the ratio between query rating and its position.
#
# We also define poor query percentage as:
#
# The percentage of all queries with rating less than 3.
#
# Write a solution to find each query_name, the quality and poor_query_percentage.
#
# Both quality and poor_query_percentage should be rounded to 2 decimal places.
#
# Return the result table in any order.

# %%
data = [['Dog', 'Golden Retriever', 1, 5], ['Dog', 'German Shepherd', 2, 5], ['Dog', 'Mule', 200, 1], ['Cat', 'Shirazi', 5, 2], ['Cat', 'Siamese', 3, 3], ['Cat', 'Sphynx', 7, 4]]
df = pd.DataFrame(data, columns=['query_name', 'result', 'position', 'rating']).astype({'query_name':'object', 'result':'object', 'position':'Int64', 'rating':'Int64'})
df
# Out:
#   query_name            result  position  rating
# 0        Dog  Golden Retriever         1       5
# 1        Dog   German Shepherd         2       5
# 2        Dog              Mule       200       1
# 3        Cat           Shirazi         5       2
# 4        Cat           Siamese         3       3
# 5        Cat            Sphynx         7       4

# %% [markdown]
# #### 2356 - Number of Unique subjects taught by each teacher
#
# Write a solution to calculate the number of unique subjects each teacher teaches in the university.
#
# Return the result table in any order.

# %%
data = [[1, 2, 3], [1, 2, 4], [1, 3, 3], [2, 1, 1], [2, 2, 1], [2, 3, 1], [2, 4, 1]]
teacher = pd.DataFrame(data, columns=['teacher_id', 'subject_id', 'dept_id']).astype({'teacher_id':'Int64', 'subject_id':'Int64', 'dept_id':'Int64'})
teacher
# Out:
#    teacher_id  subject_id  dept_id
# 0           1           2        3
# 1           1           2        4
# 2           1           3        3
# 3           2           1        1
# 4           2           2        1
# 5           2           3        1
# 6           2           4        1

# %%
df = teacher.groupby('teacher_id').agg(cnt=('subject_id','nunique')).reset_index()
df
# Out:
#    teacher_id  cnt
# 0           1    2
# 1           2    4

# %% [markdown]
# #### 1141 - User Activity for the past 30 days I
#
# Write a solution to find the daily active user count for a period of 30 days ending 2019-07-27 inclusively. A user was active on someday if they made at least one activity on that day.
#
# Return the result table in any order.

# %%
data = [[1, 1, '2019-07-20', 'open_session'], [1, 1, '2019-07-20', 'scroll_down'], [1, 1, '2019-07-20', 'end_session'], [2, 4, '2019-07-20', 'open_session'], [2, 4, '2019-07-21', 'send_message'], [2, 4, '2019-07-21', 'end_session'], [3, 2, '2019-07-21', 'open_session'], [3, 2, '2019-07-21', 'send_message'], [3, 2, '2019-07-21', 'end_session'], [4, 3, '2019-06-25', 'open_session'], [4, 3, '2019-06-25', 'end_session']]
activity = pd.DataFrame(data, columns=['user_id', 'session_id', 'activity_date', 'activity_type']).astype({'user_id':'Int64', 'session_id':'Int64', 'activity_date':'datetime64[ns]', 'activity_type':'object'})
activity
# Out:
#     user_id  session_id activity_date activity_type
# 0         1           1    2019-07-20  open_session
# 1         1           1    2019-07-20   scroll_down
# 2         1           1    2019-07-20   end_session
# 3         2           4    2019-07-20  open_session
# 4         2           4    2019-07-21  send_message
# 5         2           4    2019-07-21   end_session
# 6         3           2    2019-07-21  open_session
# 7         3           2    2019-07-21  send_message
# 8         3           2    2019-07-21   end_session
# 9         4           3    2019-06-25  open_session
# 10        4           3    2019-06-25   end_session

# %%
start_date = pd.to_datetime('2019-06-28')
end_date = pd.to_datetime('2019-07-27')

# %%
df = activity[(activity['activity_date'] >= start_date) & (activity['activity_date'] <= end_date)]

# %%
result = df.groupby('activity_date')['user_id'].nunique().reset_index(name='active_users').rename(columns={'activity_date':'day'}).sort_values('day')
result
# Out:
#          day  active_users
# 0 2019-07-20             2
# 1 2019-07-21             2

# %% [markdown]
# #### 1193 - Monthly transaction I
#
# find for each month and country, the number of transactions and their total amount, the number of approved transactions and their total amount.
#
# Return the result table in any order.

# %%
data = [[121, 'US', 'approved', 1000, '2018-12-18'], [122, 'US', 'declined', 2000, '2018-12-19'], [123, 'US', 'approved', 2000, '2019-01-01'], [124, 'DE', 'approved', 2000, '2019-01-07']]
transactions = pd.DataFrame(data, columns=['id', 'country', 'state', 'amount', 'trans_date']).astype({'id':'Int64', 'country':'object', 'state':'object', 'amount':'Int64', 'trans_date':'datetime64[ns]'})

# %%
df = pd.DataFrame(transactions)
df
# Out:
#     id country     state  amount trans_date
# 0  121      US  approved    1000 2018-12-18
# 1  122      US  declined    2000 2018-12-19
# 2  123      US  approved    2000 2019-01-01
# 3  124      DE  approved    2000 2019-01-07

# %%
df['trans_date'] = pd.to_datetime(df['trans_date'])
df['month'] = df['trans_date'].dt.to_period('M').astype(str)
df[['trans_date','month']]
# Out:
#   trans_date    month
# 0 2018-12-18  2018-12
# 1 2018-12-19  2018-12
# 2 2019-01-01  2019-01
# 3 2019-01-07  2019-01

# %%
grouped = df.groupby(['month','country'])

# %%
trans_count = grouped['id'].count().reset_index(name='trans_count')
trans_count
# Out:
#      month country  trans_count
# 0  2018-12      US            2
# 1  2019-01      DE            1
# 2  2019-01      US            1

# %%
approved_count = grouped['state'].apply(lambda x : (x == 'approved').sum()).reset_index(name='approved_count')
approved_count
# Out:
#      month country  approved_count
# 0  2018-12      US               1
# 1  2019-01      DE               1
# 2  2019-01      US               1

# %%
trans_total_amount = grouped['amount'].sum().reset_index(name='trans_total_amount')
trans_total_amount
# Out:
#      month country  trans_total_amount
# 0  2018-12      US                3000
# 1  2019-01      DE                2000
# 2  2019-01      US                2000

# %%
def sum_approved_amt(x):
    approved_rows = df.loc[x.index]
    return approved_rows[approved_rows['state'] == 'approved']['amount'].sum()
approved_total_count = grouped['amount'].apply(sum_approved_amt).reset_index(name='approved_total_amount')
approved_total_count
# Out:
#      month country  approved_total_amount
# 0  2018-12      US                   1000
# 1  2019-01      DE                   2000
# 2  2019-01      US                   2000

# %%
df.groupby(['month','country']).agg(
    trans_count = ('id', 'count'),
    approved_count = ('state',lambda x : (x == 'approved').sum()),
    trans_total_amount = ('amount','sum'),
    approved_total_amount = ('amount', lambda x : x[df.loc[x.index, 'state'] == 'approved'].sum())
).reset_index()
# Out:
#      month country  trans_count  approved_count  trans_total_amount  \
# 0  2018-12      US            2               1                3000
# 1  2019-01      DE            1               1                2000
# 2  2019-01      US            1               1                2000
#
#    approved_total_amount
# 0                   1000
# 1                   2000
# 2                   2000

# %% [markdown]
# ##### 1174 - Immediate Food Delivery II
#
# If the customer's preferred delivery date is the same as the order date, then the order is called immediate; otherwise, it is called scheduled.
#
# The first order of a customer is the order with the earliest order date that the customer made. It is guaranteed that a customer has precisely one first order.
#
# Write a solution to find the percentage of immediate orders in the first orders of all customers, rounded to 2 decimal places.

# %%
data = [[1, 1, '2019-08-01', '2019-08-02'], [2, 2, '2019-08-02', '2019-08-02'], [3, 1, '2019-08-11', '2019-08-12'], [4, 3, '2019-08-24', '2019-08-24'], [5, 3, '2019-08-21', '2019-08-22'], [6, 2, '2019-08-11', '2019-08-13'], [7, 4, '2019-08-09', '2019-08-09']]
delivery = pd.DataFrame(data, columns=['delivery_id', 'customer_id', 'order_date', 'customer_pref_delivery_date']).astype({'delivery_id':'Int64', 'customer_id':'Int64', 'order_date':'datetime64[ns]', 'customer_pref_delivery_date':'datetime64[ns]'})
df = pd.DataFrame(delivery)

# %%
df
# Out:
#    delivery_id  customer_id order_date customer_pref_delivery_date
# 0            1            1 2019-08-01                  2019-08-02
# 1            2            2 2019-08-02                  2019-08-02
# 2            3            1 2019-08-11                  2019-08-12
# 3            4            3 2019-08-24                  2019-08-24
# 4            5            3 2019-08-21                  2019-08-22
# 5            6            2 2019-08-11                  2019-08-13
# 6            7            4 2019-08-09                  2019-08-09

# %%
first_orders = df.loc[df.groupby('customer_id')['order_date'].idxmin()]
first_orders
# Out:
#    delivery_id  customer_id order_date customer_pref_delivery_date
# 0            1            1 2019-08-01                  2019-08-02
# 1            2            2 2019-08-02                  2019-08-02
# 4            5            3 2019-08-21                  2019-08-22
# 6            7            4 2019-08-09                  2019-08-09

# %%
immediate_count = (first_orders['order_date'] == first_orders['customer_pref_delivery_date']).sum()
immediate_count
# Out:
# np.int64(2)

# %%
immediate_percentage = round((immediate_count / len(first_orders)) * 100, 2)
immediate_percentage
# Out:
# np.float64(50.0)

# %%
result = pd.DataFrame({'immediate_percentage' : [immediate_percentage]})
result
# Out:
#    immediate_percentage
# 0                  50.0

# %% [markdown]
# ##### 550 - Game Play Analysis - IV
#
# Write a solution to report the fraction of players that logged in again on the day after the day they first logged in, rounded to 2 decimal places. In other words, you need to determine the number of players who logged in on the day immediately following their initial login, and divide it by the number of total players.

# %%
data = [[1, 2, '2016-03-01', 5], [1, 2, '2016-03-02', 6], [2, 3, '2017-06-25', 1], [3, 1, '2016-03-02', 0], [3, 4, '2018-07-03', 5]]
activity = pd.DataFrame(data, columns=['player_id', 'device_id', 'event_date', 'games_played']).astype({'player_id':'Int64', 'device_id':'Int64', 'event_date':'datetime64[ns]', 'games_played':'Int64'})
df = pd.DataFrame(activity)
df
# Out:
#    player_id  device_id event_date  games_played
# 0          1          2 2016-03-01             5
# 1          1          2 2016-03-02             6
# 2          2          3 2017-06-25             1
# 3          3          1 2016-03-02             0
# 4          3          4 2018-07-03             5

# %%
df['event_date'] = pd.to_datetime(df['event_date'])
first_login = df.groupby('player_id')['event_date'].min().reset_index()
first_login
# Out:
#    player_id event_date
# 0          1 2016-03-01
# 1          2 2017-06-25
# 2          3 2016-03-02

# %%
first_login['next_day'] = first_login['event_date'] + pd.Timedelta(days=1)
first_login
# Out:
#    player_id event_date   next_day
# 0          1 2016-03-01 2016-03-02
# 1          2 2017-06-25 2017-06-26
# 2          3 2016-03-02 2016-03-03

# %%
merged = pd.merge(df, first_login, left_on = ['player_id','event_date'], right_on=['player_id','next_day'])
merged
# Out:
#    player_id  device_id event_date_x  games_played event_date_y   next_day
# 0          1          2   2016-03-02             6   2016-03-01 2016-03-02

# %%
fraction = round(len(merged['player_id'].unique()) / len(first_login) ,2)
fraction
# Out:
# 0.33

# %% [markdown]
# ##### 1070 - Product Sales Analysis III
#
# Write a solution to find all sales that occurred in the first year each product was sold.
#
# For each product_id, identify the earliest year it appears in the Sales table.
#
# Return all sales entries for that product in that year.
#
# Return a table with the following columns: product_id, first_year, quantity, and price.
# Return the result in any order.

# %%
data = [[1, 100, 2008, 10, 5000], [2, 100, 2009, 12, 5000], [7, 200, 2011, 15, 9000]]
sales = pd.DataFrame(data, columns=['sale_id', 'product_id', 'year', 'quantity', 'price']).astype({'sale_id':'Int64', 'product_id':'Int64', 'year':'Int64', 'quantity':'Int64', 'price':'Int64'})
df = pd.DataFrame(sales)
df
# Out:
#    sale_id  product_id  year  quantity  price
# 0        1         100  2008        10   5000
# 1        2         100  2009        12   5000
# 2        7         200  2011        15   9000

# %%
first_year = df.groupby('product_id', as_index=False)['year'].min()
first_year
# Out:
#    product_id  year
# 0         100  2008
# 1         200  2011

# %%
merged_df = pd.merge(df, first_year, on = ['product_id', 'year'])
merged_df
# Out:
#    sale_id  product_id  year  quantity  price
# 0        1         100  2008        10   5000
# 1        7         200  2011        15   9000

# %%
merged_df.rename(columns={'year':'first_year'}, inplace=True)
result = merged_df[['product_id', 'first_year', 'quantity', 'price']]
result
# Out:
#    product_id  first_year  quantity  price
# 0         100        2008        10   5000
# 1         200        2011        15   9000
